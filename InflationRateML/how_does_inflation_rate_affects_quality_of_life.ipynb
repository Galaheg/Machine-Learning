# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('rateinf.csv')
avg_inflation = df.mean()
plt.title("Average Inflation")
plt.xlabel("Country")
plt.ylabel("Inflation")
avg_inflation.plot(kind='line')
plt.show()
# Out:
# C:\Users\hemre\AppData\Local\Temp\ipykernel_12540\224936365.py:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_inflation = df.mean()

# %%
df = pd.read_csv('rateinf.csv', index_col='Country')
inflation_changes1 = df['2019'] - df['2018']
countries_with_increasing_inflation = df[inflation_changes1 > 0]
for country in countries_with_increasing_inflation.index:
    print(country)
# Out:
# Czechia
# Ireland
# Latvia
# Hungary
# Netherlands
# Poland
# Slovakia
# Iceland

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Read in the data for 2018 and 2019
df_2018 = pd.read_csv('wh2018.csv')
df_2019 = pd.read_csv('wh2019.csv')

# Specify the countries to include
countries = [ 'Ireland', 'Latvia', 'Hungary', 'Netherlands', 'Poland', 'Slovakia', 'Iceland']

# Filter the data for the specified countries
df_2018_filtered = df_2018[df_2018['Country'].isin(countries)]
df_2019_filtered = df_2019[df_2019['Country'].isin(countries)]
# Create an empty dataframe with two columns: 'Country' and 'Score'

df_2019_filtered=df_2019_filtered.set_index("Country")
df_2018_filtered=df_2018_filtered.set_index("Country")

# Calculate the change in happiness score between 2018 and 2019 for each country
happiness_changes = pd.DataFrame()
happiness_changes["Score"] = df_2019_filtered['Score'] - df_2018_filtered['Score']
#df3=df_2019_filtered["Score"].subtract(df_2018_filtered["Score"])
df = pd.DataFrame(columns=['Country', 'Score'])
happiness_changes.reset_index(inplace=True)# reset index to get country names


# Create a bar chart with 'Country' on the x-axis and 'Score' on the y-axis
"""plt.bar(df['Country'], df['Score'])
plt.title("Change in Happiness Scores Between 2018 and 2019")
plt.xlabel("Country")
plt.ylabel("Change in Happiness Score")
plt.show()"""

# Data to plot
x = happiness_changes["Country"]
y = happiness_changes["Score"]

# Create the bar chart
plt.bar(x, y, color=['red', 'green', 'blue'])

# Add axis labels
plt.xlabel('Category')
plt.ylabel('Value')

# Add a title
plt.title('Values by Category')

# Show the chart
plt.show()

print(happiness_changes.head(8))
# Out:
#        Country  Score
# 0      Iceland -0.001
# 1  Netherlands  0.047
# 2      Ireland  0.044
# 3     Slovakia  0.025
# 4       Poland  0.059
# 5       Latvia  0.007
# 6      Hungary  0.138
